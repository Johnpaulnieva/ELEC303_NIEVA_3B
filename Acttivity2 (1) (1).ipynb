# %% [markdown]
# <h2>ACTIVITY 2 - UK ROAD ACCIDENT</h2>

# %% [markdown]
# <h4>Analyst : John Paul R. Nieva</h4>

# %% [markdown]
# <h2>1.) IMPORT NECESSARY LIBRARIES</h2>

# %%
#import libraries
import numpy as np
import pandas as pd
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %% [markdown]
# <h2>2.) CONVERT DATASET TO DATAFRAME</h2>

# %%
accident = pd.read_csv("C:\\Users\\Leenitte\\Downloads\\ACTIVITY 2\\uk_road_accident.csv")
accident
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious      5/6/2019  51.506187
# 1       200701BS65737           Serious      2/7/2019  51.495029
# 2       200701BS66127           Serious    26-08-2019  51.517715
# 3       200701BS66128           Serious    16-08-2019  51.495478
# 4       200701BS66837            Slight      3/9/2019  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight    18-02-2022  57.374005
# 660675  201091NM01881            Slight    21-02-2022  57.232273
# 660676  201091NM01935            Slight    23-02-2022  57.585044
# 660677  201091NM01964           Serious    23-02-2022  57.214898
# 660678  201091NM02142           Serious    28-02-2022  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# ...

# %% [markdown]
# <H3>3.) CHECK DATAFRAME AND INFORMATION</H3>

# %%
accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660679 entries, 0 to 660678
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Index                    660679 non-null  object
#  1   Accident_Severity        660679 non-null  object
#  2   Accident Date            660679 non-null  object
#  3   Latitude                 660654 non-null  float64
#  4   Light_Conditions         660679 non-null  object
#  5   District Area            660679 non-null  object
#  6   Longitude                660653 non-null  float64
#  7   Number_of_Casualties     660679 non-null  int64
#  8   Number_of_Vehicles       660679 non-null  int64
#  9   Road_Surface_Conditions  659953 non-null  object
#  10  Road_Type                656159 non-null  object
#  11  Urban_or_Rural_Area      660664 non-null  object
#  12  Weather_Conditions       646551 non-null  object
# ...

# %% [markdown]
# <H2>4.) CHECK BASIC DESCRIPTIVE STATISTICS</H2>

# %%
accident.describe()
# Out:
#             Latitude      Longitude  Number_of_Casualties  Number_of_Vehicles
# count  660654.000000  660653.000000         660679.000000       660679.000000
# mean       52.553866      -1.431210              1.357040            1.831255
# std         1.406922       1.383330              0.824847            0.715269
# min        49.914430      -7.516225              1.000000            1.000000
# 25%        51.490690      -2.332291              1.000000            1.000000
# 50%        52.315641      -1.411667              1.000000            2.000000
# 75%        53.453452      -0.232869              1.000000            2.000000
# max        60.757544       1.762010             68.000000           32.000000

# %% [markdown]
# <h2>5.) CALL EACH COLUMN INDIVIDUALLY</h2>

# %%
accident['Index']
# Out:
# 0         200701BS64157
# 1         200701BS65737
# 2         200701BS66127
# 3         200701BS66128
# 4         200701BS66837
#               ...
# 660674    201091NM01760
# 660675    201091NM01881
# 660676    201091NM01935
# 660677    201091NM01964
# 660678    201091NM02142
# Name: Index, Length: 660679, dtype: object

# %%
accident['Accident_Severity']
# Out:
# 0         Serious
# 1         Serious
# 2         Serious
# 3         Serious
# 4          Slight
#            ...
# 660674     Slight
# 660675     Slight
# 660676     Slight
# 660677    Serious
# 660678    Serious
# Name: Accident_Severity, Length: 660679, dtype: object

# %%
accident['Accident Date']
# Out:
# 0           5/6/2019
# 1           2/7/2019
# 2         26-08-2019
# 3         16-08-2019
# 4           3/9/2019
#              ...
# 660674    18-02-2022
# 660675    21-02-2022
# 660676    23-02-2022
# 660677    23-02-2022
# 660678    28-02-2022
# Name: Accident Date, Length: 660679, dtype: object

# %%
accident['Latitude']
# Out:
# 0         51.506187
# 1         51.495029
# 2         51.517715
# 3         51.495478
# 4         51.488576
#             ...
# 660674    57.374005
# 660675    57.232273
# 660676    57.585044
# 660677    57.214898
# 660678    57.575210
# Name: Latitude, Length: 660679, dtype: float64

# %%
accident['Light_Conditions']
# Out:
# 0               Darkness - lights lit
# 1                            Daylight
# 2         Darkness - lighting unknown
# 3                            Daylight
# 4               Darkness - lights lit
#                      ...
# 660674                       Daylight
# 660675         Darkness - no lighting
# 660676                       Daylight
# 660677         Darkness - no lighting
# 660678                       Daylight
# Name: Light_Conditions, Length: 660679, dtype: object

# %%
accident['District Area']
# Out:
# 0         Kensington and Chelsea
# 1         Kensington and Chelsea
# 2         Kensington and Chelsea
# 3         Kensington and Chelsea
# 4         Kensington and Chelsea
#                    ...
# 660674                  Highland
# 660675                  Highland
# 660676                  Highland
# 660677                  Highland
# 660678                  Highland
# Name: District Area, Length: 660679, dtype: object

# %%
accident['Longitude']
# Out:
# 0        -0.209082
# 1        -0.173647
# 2        -0.210215
# 3        -0.202731
# 4        -0.192487
#             ...
# 660674   -3.467828
# 660675   -3.809281
# 660676   -3.862727
# 660677   -3.823997
# 660678   -3.895673
# Name: Longitude, Length: 660679, dtype: float64

# %%
accident['Number_of_Casualties']
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 660674    2
# 660675    1
# 660676    1
# 660677    1
# 660678    1
# Name: Number_of_Casualties, Length: 660679, dtype: int64

# %%
accident['Number_of_Vehicles']
# Out:
# 0         2
# 1         2
# 2         3
# 3         4
# 4         2
#          ..
# 660674    1
# 660675    1
# 660676    3
# 660677    2
# 660678    1
# Name: Number_of_Vehicles, Length: 660679, dtype: int64

# %%
accident['Road_Surface_Conditions']
# Out:
# 0                  Dry
# 1          Wet or damp
# 2                  Dry
# 3                  Dry
# 4                  Dry
#               ...
# 660674             Dry
# 660675    Frost or ice
# 660676    Frost or ice
# 660677     Wet or damp
# 660678     Wet or damp
# Name: Road_Surface_Conditions, Length: 660679, dtype: object

# %%
accident['Road_Type']
# Out:
# 0         Single carriageway
# 1         Single carriageway
# 2                        NaN
# 3         Single carriageway
# 4                        NaN
#                  ...
# 660674    Single carriageway
# 660675    Single carriageway
# 660676    Single carriageway
# 660677    Single carriageway
# 660678      Dual carriageway
# Name: Road_Type, Length: 660679, dtype: object

# %%
accident['Urban_or_Rural_Area']
# Out:
# 0         Urban
# 1         Urban
# 2         Urban
# 3         Urban
# 4         Urban
#           ...
# 660674    Rural
# 660675    Rural
# 660676    Rural
# 660677    Rural
# 660678    Rural
# Name: Urban_or_Rural_Area, Length: 660679, dtype: object

# %%
accident['Weather_Conditions']
# Out:
# 0            Fine no high winds
# 1         Raining no high winds
# 2                           NaN
# 3            Fine no high winds
# 4                           NaN
#                   ...
# 660674       Fine no high winds
# 660675       Fine no high winds
# 660676       Fine no high winds
# 660677       Fine no high winds
# 660678    Snowing no high winds
# Name: Weather_Conditions, Length: 660679, dtype: object

# %%
accident['Vehicle_Type']
# Out:
# 0                                          Car
# 1                                          Car
# 2                        Taxi/Private hire car
# 3         Bus or coach (17 or more pass seats)
# 4                                Other vehicle
#                           ...
# 660674                                     Car
# 660675                                     Car
# 660676                                     Car
# 660677                   Motorcycle over 500cc
# 660678                                     Car
# Name: Vehicle_Type, Length: 660679, dtype: object

# %%
accident.isnull().sum()
# Out:
# Index                          0
# Accident_Severity              0
# Accident Date                  0
# Latitude                      25
# Light_Conditions               0
# District Area                  0
# Longitude                     26
# Number_of_Casualties           0
# Number_of_Vehicles             0
# Road_Surface_Conditions      726
# Road_Type                   4520
# Urban_or_Rural_Area           15
# Weather_Conditions         14128
# Vehicle_Type                   0
# dtype: int64

# %% [markdown]
# <h2>6.) CHECK FOR NULL VALUES</h2>

# %%
accident.isnull().sum()
# Out:
# Index                          0
# Accident_Severity              0
# Accident Date                  0
# Latitude                      25
# Light_Conditions               0
# District Area                  0
# Longitude                     26
# Number_of_Casualties           0
# Number_of_Vehicles             0
# Road_Surface_Conditions      726
# Road_Type                   4520
# Urban_or_Rural_Area           15
# Weather_Conditions         14128
# Vehicle_Type                   0
# dtype: int64

# %% [markdown]
# <h2>7.) FILL NULL VALUES WITH STATISTCAL VALUES</h2>

# %%
accident['Latitude'] = accident['Latitude'] .fillna(accident['Latitude'].mean())
accident['Longitude'] = accident['Longitude'] .fillna(accident['Longitude'].mean())
accident['Road_Surface_Conditions'] = accident['Road_Surface_Conditions'] .fillna(accident['Road_Surface_Conditions'].mode()[0])
accident['Road_Type'] = accident['Road_Type'] .fillna(accident['Road_Type'].mode()[0])
accident['Urban_or_Rural_Area'] = accident['Urban_or_Rural_Area'] .fillna(accident['Urban_or_Rural_Area'].mode()[0])
accident['Weather_Conditions'] = accident['Weather_Conditions'] .fillna(accident['Weather_Conditions'].mode()[0])

# %% [markdown]
# <h2>8.) CHECK COLUMN DATA TYPES</h2>

# %%
accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660679 entries, 0 to 660678
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Index                    660679 non-null  object
#  1   Accident_Severity        660679 non-null  object
#  2   Accident Date            660679 non-null  object
#  3   Latitude                 660679 non-null  float64
#  4   Light_Conditions         660679 non-null  object
#  5   District Area            660679 non-null  object
#  6   Longitude                660679 non-null  float64
#  7   Number_of_Casualties     660679 non-null  int64
#  8   Number_of_Vehicles       660679 non-null  int64
#  9   Road_Surface_Conditions  660679 non-null  object
#  10  Road_Type                660679 non-null  object
#  11  Urban_or_Rural_Area      660679 non-null  object
#  12  Weather_Conditions       660679 non-null  object
# ...

# %%
accident['Index'] = accident ['Index'].astype('category')

# %%
accident['Accident_Severity'] = accident ['Accident_Severity'].astype('category')

# %%
accident['Accident Date'] = accident ['Accident Date'].astype('category')

# %%
accident['Light_Conditions'] = accident ['Light_Conditions'].astype('category')

# %%
accident['District Area'] = accident ['District Area'].astype('category')

# %%
accident['Road_Surface_Conditions'] = accident ['Road_Surface_Conditions'].astype('category')

# %%
accident['Road_Type'] = accident ['Road_Type'].astype('category')

# %%
accident['Urban_or_Rural_Area'] = accident ['Urban_or_Rural_Area'].astype('category')

# %%
accident['Weather_Conditions'] = accident ['Weather_Conditions'].astype('category')

# %%
accident['Vehicle_Type'] = accident ['Vehicle_Type'].astype('category')

# %%
accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660679 entries, 0 to 660678
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Index                    660679 non-null  category
#  1   Accident_Severity        660679 non-null  category
#  2   Accident Date            660679 non-null  category
#  3   Latitude                 660679 non-null  float64
#  4   Light_Conditions         660679 non-null  category
#  5   District Area            660679 non-null  category
#  6   Longitude                660679 non-null  float64
#  7   Number_of_Casualties     660679 non-null  int64
#  8   Number_of_Vehicles       660679 non-null  int64
#  9   Road_Surface_Conditions  660679 non-null  category
#  10  Road_Type                660679 non-null  category
#  11  Urban_or_Rural_Area      660679 non-null  category
#  12  Weather_Conditions       660679 non-null  category
# ...

# %%
accident['Weather_Conditions']
# Out:
# 0            Fine no high winds
# 1         Raining no high winds
# 2            Fine no high winds
# 3            Fine no high winds
# 4            Fine no high winds
#                   ...
# 660674       Fine no high winds
# 660675       Fine no high winds
# 660676       Fine no high winds
# 660677       Fine no high winds
# 660678    Snowing no high winds
# Name: Weather_Conditions, Length: 660679, dtype: category
# Categories (8, object): ['Fine + high winds', 'Fine no high winds', 'Fog or mist', 'Other', 'Raining + high winds', 'Raining no high winds', 'Snowing + high winds', 'Snowing no high winds']

# %% [markdown]
# <h2>QUESTION 1</h2>
# <h2>Which vehicle type is most common in accidents with more than 3 casualties?</h2>

# %%
accident[accident['Number_of_Casualties']>3]['Vehicle_Type'].mode()[0]
# Out:
# 'Car'

# %% [markdown]
# <h3>Insight: Large vehicles often contribute to high-casualty crashes is car.</h3>

# %% [markdown]
# <h2>QUESTION 2: </h2>
# <H2>Were there fatal accidents on icy roads?</H2>

# %%
fatal_icy = accident[(accident["Accident_Severity"] == "Fatal") & (accident["Road_Surface_Conditions"] == "Frost or ice")]
fatal_icy
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 32500   200705DD21895             Fatal    14-12-2019  53.472460
# 39507   200706M085541             Fatal    22-12-2019  53.458591
# 49246        2.01E+12             Fatal    11/12/2019  55.340563
# 53478        2.01E+12             Fatal    10/12/2019  54.150003
# 68446   2007170S23397             Fatal    11/12/2019  54.605826
# ...               ...               ...           ...        ...
# 655259       2.01E+12             Fatal      2/1/2022  51.702548
# 658939  201063AC00710             Fatal     10/1/2022  51.745470
# 659966  201063DP00210             Fatal      6/1/2022  52.280957
# 660038  201063DP07410             Fatal    18-02-2022  52.013451
# 660393  201091NE00716             Fatal    17-01-2022  57.533183
#
#               Light_Conditions     District Area  Longitude  \
# 32500    Darkness - lights lit        St. Helens  -2.681090
# 39507    Darkness - lights lit          Trafford  -2.384770
# ...

# %% [markdown]
# <h3>Insight: This shows how often icy surfaces lead to fatal crashes — a major winter road safety risk.</h3>

# %% [markdown]
# <h2>QUESTION 3: </h2>
# <H2>Which accidents involved more than 3 vehicles in rainy conditions?</H2>

# %%
rainy_multi = accident[(accident["Weather_Conditions"] == "Raining no high winds") & (accident["Number_of_Vehicles"] > 3)]
rainy_multi
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 1148    200701CW10147            Slight    23-02-2019  51.503217
# 2013    200701CW11215            Slight    18-11-2019  51.527966
# 2373    200701CW65828            Slight      2/7/2019  51.510474
# 5782    200701HT68459            Slight     8/12/2019  51.509203
# 5848    200701ID60008            Slight    23-02-2019  51.457470
# ...               ...               ...           ...        ...
# 659758  201063CP14110            Slight      1/6/2022  51.720057
# 659846  201063CP22910            Slight      5/9/2022  51.804360
# 660155  201063DP19310            Slight    14-07-2022  51.948986
# 660301  201063DP34410            Slight    29-08-2022  52.095149
# 660395  201091NE01022            Slight    23-01-2022  57.692707
#
#               Light_Conditions              District Area  Longitude  \
# 1148     Darkness - lights lit                Westminster  -0.150986
# ...

# %% [markdown]
# <h3>Insight: Rain often reduces visibility and braking efficiency, increasing multi-vehicle collisions.</h3>

# %% [markdown]
# <h2>QUESTION 4: </h2>
# <H2>Which weather condition is most common in fatal rural accidents?</H2>

# %%
accident[(accident['Accident_Severity']=='Fatal') & (accident['Urban_or_Rural_Area']=='Rural')]['Weather_Conditions'].mode()[0]
# Out:
# 'Fine no high winds'

# %% [markdown]
# <h3>Insight: Certain weather events make rural roads more fatal.</h3>

# %% [markdown]
# <h2>QUESTION 5: </h2>
# <H2>Which district area has the highest mean casualties during daylight?</H2>

# %%
accident[accident['Light_Conditions']=='Daylight'].groupby('District Area')['Number_of_Casualties'].mean().sort_values(ascending=False).head(1)
# Out:
# District Area
# Blaeu Gwent    1.685897
# Name: Number_of_Casualties, dtype: float64

# %% [markdown]
# <h3>Insight: Even in good visibility, some districts are riskier.</h3>

# %% [markdown]
# <h2>QUESTION 6: </h2>
# <H2>Which accidents had more than 10 casualties?</H2>

# %%
mass_casualty = accident[accident["Number_of_Casualties"] > 10]
mass_casualty
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 20532   200701YE62678            Slight    14-05-2019  51.682248
# 20720   200701YE80124            Slight    19-02-2019  51.682565
# 25838   200704BA07065           Serious    13-04-2019  54.053503
# 26297   200704BC07088            Slight      6/6/2019  54.159217
# 29814   200704FL07056           Serious      4/7/2019  53.702761
# ...               ...               ...           ...        ...
# 634449       2.01E+12            Slight      7/6/2022  51.094768
# 654314  201060L117697            Slight    30-06-2022  53.097795
# 656251       2.01E+12            Slight    26-01-2022  51.659673
# 657165       2.01E+12           Serious      1/6/2022  51.405890
# 659618  201063BC21310            Slight    24-09-2022  52.062828
#
#              Light_Conditions          District Area  Longitude  \
# 20532   Darkness - lights lit                Enfield  -0.034047
# ...

# %% [markdown]
# <h3>Insight: These are rare but extremely severe accidents, often requiring emergency response planning.</h3>

# %% [markdown]
# <h2>QUESTION 7: </h2>
# <H2>Which accidents happened in rural areas during darkness?</H2>

# %%
accident[(accident['Urban_or_Rural_Area'] == 'Rural') & (accident['Light_Conditions'] != 'Daylight')]
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 5844    200701ID60003            Slight      5/2/2019  51.464588
# 6101    200701JC30253            Slight    29-04-2019  51.616921
# 6223    200701JC64859            Slight    15-07-2019  51.616088
# 6421    200701JC67563            Slight    17-10-2019  51.634365
# 6455    200701JC67845           Serious    30-11-2019  51.636691
# ...               ...               ...           ...        ...
# 660666  201091NM00770            Slight    21-01-2022  56.879446
# 660669  201091NM00903            Slight    24-01-2022  57.484296
# 660670  201091NM00939            Slight    25-01-2022  57.574536
# 660675  201091NM01881            Slight    21-02-2022  57.232273
# 660677  201091NM01964           Serious    23-02-2022  57.214898
#
#                    Light_Conditions   District Area  Longitude  \
# 5844          Darkness - lights lit      Hillingdon  -0.493029
# ...

# %% [markdown]
# <h3>Insight:Filters rural-night accidents, which are often riskier.</h3>

# %% [markdown]
# <h2>QUESTION 8: </h2>
# <H2>Were there fatal accidents in snowy conditions?</H2>

# %%
accident[(accident['Accident_Severity'] == 'Fatal') & (accident['Road_Surface_Conditions'] == 'Snow')]
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 45468        2.01E+12             Fatal    22-01-2019  55.071026
# 168093  200763AC09107             Fatal    19-03-2019  51.764514
# 181135  200797UA70301             Fatal    21-01-2019  55.735439
# 273353       2.01E+12             Fatal    20-03-2020  52.597636
# 281688       2.01E+12             Fatal    23-11-2020  52.884127
# 283188  200837G024570             Fatal    23-03-2020  52.040723
# 297177  200843R115048             Fatal      6/4/2020  51.477721
# 341333       2.01E+12             Fatal      1/2/2020  57.420306
# 409390       2.01E+12             Fatal    29-12-2021  53.644419
# 414214  2009160B05100             Fatal    25-12-2021  53.594587
# 489124       2.01E+12             Fatal      4/2/2021  51.307805
# 510545       2.01E+12             Fatal    21-12-2021  55.893149
# 510572       2.01E+12             Fatal    27-12-2021  55.517259
# ...

# %% [markdown]
# <h3>Insight: Snow-related fatal crashes can be identified directly.</h3>

# %% [markdown]
# <h2>QUESTION 9: </h2>
# <H2>Which accidents involve only 1 vehicle but result in fatalities?</H2>

# %%
accident[(accident['Number_of_Vehicles'] == 1) & (accident['Accident_Severity'] == 'Fatal')]
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 20      200701BS68301             Fatal    24-10-2019  51.505996
# 21      200701BS68302             Fatal    24-11-2019  51.486795
# 2368    200701CW65735             Fatal    17-07-2019  51.490623
# 2440    200701CW66615             Fatal      7/8/2019  51.488756
# 2451    200701CW67150             Fatal    27-09-2019  51.490156
# ...               ...               ...           ...        ...
# 660470  201091NH00529             Fatal    29-01-2022  58.475726
# 660519  201091NJ01533             Fatal      2/2/2022  58.495554
# 660565  201091NJ11329             Fatal    15-08-2022  57.871514
# 660581  201091NJ14695             Fatal    21-10-2022  58.445475
# 660627  201091NL00060             Fatal      6/1/2022  60.241195
#
#              Light_Conditions           District Area  Longitude  \
# 20                   Daylight  Kensington and Chelsea  -0.214277
# ...

# %% [markdown]
# <h3>Insight: Single-vehicle fatal crashes highlight solo risks.</h3>

# %% [markdown]
# <h2>QUESTION 10: </h2>
# <H2>Were there accidents in daylight with only 1 casualty?</H2>

# %%
accident[(accident['Light_Conditions'] == 'Daylight') & (accident['Number_of_Casualties'] == 1)]
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 1       200701BS65737           Serious      2/7/2019  51.495029
# 3       200701BS66128           Serious    16-08-2019  51.495478
# 6       200701BS67207           Serious      5/9/2019  51.501405
# 9       200701BS67543            Slight    18-10-2019  51.484539
# 11      200701BS67747             Fatal     2/11/2019  51.499127
# ...               ...               ...           ...        ...
# 660667  201091NM00837            Slight    23-01-2022  57.076929
# 660671  201091NM01053            Slight    29-01-2022  57.572162
# 660672  201091NM01085           Serious    29-01-2022  57.170725
# 660676  201091NM01935            Slight    23-02-2022  57.585044
# 660678  201091NM02142           Serious    28-02-2022  57.575210
#
#        Light_Conditions           District Area  Longitude  \
# 1              Daylight  Kensington and Chelsea  -0.173647
# 3              Daylight  Kensington and Chelsea  -0.202731
# ...

# %% [markdown]
# <h1>Insight: Simple daylight minor accidents are visible.</h1>

# %% [markdown]
# <h2>QUESTION 11: </h2>
# <H2>Can accident severity be predicted using weather, road type, and light conditions?</H2>

# %%
accident.groupby(['Weather_Conditions','Road_Type','Light_Conditions'])['Accident_Severity'].value_counts()
# Out:
# Weather_Conditions     Road_Type         Light_Conditions             Accident_Severity
# Fine + high winds      Dual carriageway  Darkness - lighting unknown  Slight                 9
#                                                                       Serious                3
#                                                                       Fatal                  1
#                                          Darkness - lights lit        Slight               281
#                                                                       Serious               50
#                                                                                           ...
# Snowing no high winds  Slip road         Darkness - no lighting       Serious                4
#                                                                       Fatal                  0
#                                          Daylight                     Slight                30
# ...

# %% [markdown]
# <h3>Insight: Certain combinations like poor weather,rural road types,and dark conditions show higher accident severity,suggesting these factors together help predict rick.</h3>

# %% [markdown]
# <h2>QUESTION 12: </h2>
# <H2>Which accident severity is most common overall?</H2>

# %%
severity_counts = accident['Accident_Severity'].value_counts()
print(severity_counts)
# Out:
# Accident_Severity
# Slight     563801
# Serious     88217
# Fatal        8661
# Name: count, dtype: int64

# %% [markdown]
# <h3>Insight: Most common Accident Severity is Slight in overall.</h3>

# %% [markdown]
# <h2>QUESTION 13: </h2>
# <H2>Are multi_vehicle accindents associated with higher than single-vehicle ones?</H2>

# %%
accident['Multi_Vehicle'] = accident['Number_of_Vehicles'] > 1
accident.groupby('Multi_Vehicle')['Accident_Severity'].value_counts()
# Out:
# Multi_Vehicle  Accident_Severity
# False          Slight               157962
#                Serious               38940
#                Fatal                  3885
# True           Slight               405839
#                Serious               49277
#                Fatal                  4776
# Name: count, dtype: int64

# %% [markdown]
# <h3>Insight:Multi Vehicle accident are more frequent, but single vehicle accident tend to be more severe on average.</h3>

# %% [markdown]
# <h2>QUESTION 14: </h2>
# <H2>Which light condition has the highest number of serious/fatal accidents?</H2>

# %%
serious_fatal = accident[accident['Accident_Severity'].isin(['Serious','Fatal'])]
light_counts = serious_fatal['Light_Conditions'].value_counts()
print(light_counts)
# Out:
# Light_Conditions
# Daylight                       65835
# Darkness - lights lit          20990
# Darkness - no lighting          8786
# Darkness - lighting unknown      862
# Darkness - lights unlit          405
# Name: count, dtype: int64

# %% [markdown]
# <h3>Insight:The highest light condition fatal accidents is daylight.</h3>

# %% [markdown]
# <h2>QUESTION 15: </h2>
# <H2>Are accidents more severe during darkness compared to daylight?</H2>

# %%
light_severity = accident.groupby('Light_Conditions')['Accident_Severity'].value_counts()
print(light_severity)
# Out:
# Light_Conditions             Accident_Severity
# Darkness - lighting unknown  Slight                 5622
#                              Serious                 794
#                              Fatal                    68
# Darkness - lights lit        Slight               108345
#                              Serious               19130
#                              Fatal                  1860
# Darkness - lights unlit      Slight                 2138
#                              Serious                 360
#                              Fatal                    45
# Darkness - no lighting       Slight                28651
#                              Serious                7174
#                              Fatal                  1612
# Daylight                     Slight               419045
#                              Serious               60759
#                              Fatal                  5076
# Name: count, dtype: int64

# %% [markdown]
# <h3>Accidents in daylight are more frequent overall, but darkness (especially without lighting) has a higher proportion of serious and fatal accidents. This suggests that poor visibility significantly increases accident severity.</h3>

# %% [markdown]
# <h2>QUESTION 16: </h2>
# <H2>Does weather condition affect accident severity?</H2>

# %%
weather_severity = accident.groupby('Weather_Conditions')['Accident_Severity'].value_counts()
print(weather_severity)
# Out:
# Weather_Conditions     Accident_Severity
# Fine + high winds      Slight                 7134
#                        Serious                1245
#                        Fatal                   175
# Fine no high winds     Slight               454521
#                        Serious               73285
#                        Fatal                  7207
# Fog or mist            Slight                 2963
#                        Serious                 483
#                        Fatal                    82
# Other                  Slight                15184
#                        Serious                1801
#                        Fatal                   165
# Raining + high winds   Slight                 8209
#                        Serious                1261
#                        Fatal                   145
# Raining no high winds  Slight                69380
#                        Serious                9468
#                        Fatal                   848
# ...

# %% [markdown]
# <h3>Insight: Most accidents happen in fine weather, but the proportion of fatal/serious cases increases during fog, rain, or snow.</h3>

# %% [markdown]
# <h2>QUESTION 17: </h2>
# <H2>Is the number of vehicles correlated with the number of casualties?</H2>

# %%
accident[['Number_of_Vehicles','Number_of_Casualties']].corr()
# Out:
#                       Number_of_Vehicles  Number_of_Casualties
# Number_of_Vehicles              1.000000              0.228889
# Number_of_Casualties            0.228889              1.000000

# %% [markdown]
# <h3>Insight: A positive correlation is expected, meaning that when more vehicles are involved, the number of casualties also increases.</h3>

# %% [markdown]
# <h2>QUESTION 18: </h2>
# <H2>Are urban accidents less severe than rural ones?</H2>

# %%
urban_severity = accident.groupby('Urban_or_Rural_Area')['Accident_Severity'].value_counts()
print(urban_severity)
# Out:
# Urban_or_Rural_Area  Accident_Severity
# Rural                Slight               196077
#                      Serious               37312
#                      Fatal                  5601
# Unallocated          Slight                   10
#                      Serious                   1
#                      Fatal                     0
# Urban                Slight               367714
#                      Serious               50904
#                      Fatal                  3060
# Name: count, dtype: int64

# %% [markdown]
# <h3>Insight: Urban areas have more accidents overall (due to higher traffic), but rural accidents tend to be more severe.</h3>

# %% [markdown]
# <h2>QUESTION 19: </h2>
# <H2>Does road type influence accident severity?</H2>

# %%
road_severity = accident.groupby('Road_Type')['Accident_Severity'].value_counts()
print(road_severity)
# Out:
# Road_Type           Accident_Severity
# Dual carriageway    Slight                85863
#                     Serious               11746
#                     Fatal                  1815
# One way street      Slight                11809
#                     Serious                1655
#                     Fatal                    95
# Roundabout          Slight                40185
#                     Serious                3665
#                     Fatal                   142
# Single carriageway  Slight               419563
#                     Serious               70540
#                     Fatal                  6560
# Slip road           Slight                 6381
#                     Serious                 611
#                     Fatal                    49
# Name: count, dtype: int64

# %% [markdown]
# <h3>Insight: Single carriageways account for the majority of accidents, while dual carriageways and motorways have fewer accidents but a higher share of severe cases.</h3>

# %% [markdown]
# <h2>QUESTION 20: </h2>
# <H2>Is accident severity correlated with number of casualties?</H2>

# %%
severity_map = {'Slight': 1, 'Serious': 2, 'Fatal': 3}
accident['Severity_Num'] = accident['Accident_Severity'].map(severity_map)

accident[['Severity_Num','Number_of_Casualties']].corr()
# Out:
#                       Severity_Num  Number_of_Casualties
# Severity_Num              1.000000              0.087886
# Number_of_Casualties      0.087886              1.000000

# %% [markdown]
# <h3>Insight: Higher severity values (Serious, Fatal) should show a moderate positive correlation with the number of casualties.</h3>

# %% [markdown]
# <h2>QUESTION 21: </h2>
# <H2>Is accident severity correlated with number of vehicles?</H2>

# %%
accident[['Severity_Num','Number_of_Vehicles']].corr()
# Out:
#                     Severity_Num  Number_of_Vehicles
# Severity_Num            1.000000           -0.075324
# Number_of_Vehicles     -0.075324            1.000000

# %% [markdown]
# <h3>Insight: The correlation is usually weak, showing that severity is not strongly determined by the number of vehicles.</h3>

# %% [markdown]
# <h2>QUESTION 22: </h2>
# <H2>Is accident severity related to the number of casualties?<H</H2>

# %%
casualty_severity = accident.groupby('Number_of_Casualties')['Accident_Severity'].value_counts()
print(casualty_severity)
# Out:
# Number_of_Casualties  Accident_Severity
# 1                     Slight               434927
#                       Serious               64271
#                       Fatal                  4843
# 2                     Slight                91471
#                       Serious               14495
#                                             ...
# 62                    Serious                   0
#                       Slight                    0
# 68                    Fatal                     1
#                       Serious                   0
#                       Slight                    0
# Name: count, Length: 108, dtype: int64

# %% [markdown]
# <h3>Insight: Accidents with more casualties are less frequent but more severe on average.</h3>

# %% [markdown]
# <h2>QUESTION 23: </h2>
# <H2>By urban vs rural area, is the number of vehicles correlated with casualties?</H2>

# %%
area_corr = accident.groupby('Urban_or_Rural_Area')[['Number_of_Vehicles','Number_of_Casualties']].corr()
print(area_corr)
# Out:
#                                           Number_of_Vehicles  \
# Urban_or_Rural_Area
# Rural               Number_of_Vehicles              1.000000
#                     Number_of_Casualties            0.236078
# Unallocated         Number_of_Vehicles              1.000000
#                     Number_of_Casualties            0.055902
# Urban               Number_of_Vehicles              1.000000
#                     Number_of_Casualties            0.217615
#
#                                           Number_of_Casualties
# Urban_or_Rural_Area
# Rural               Number_of_Vehicles                0.236078
#                     Number_of_Casualties              1.000000
# Unallocated         Number_of_Vehicles                0.055902
#                     Number_of_Casualties              1.000000
# Urban               Number_of_Vehicles                0.217615
#                     Number_of_Casualties              1.000000

# %% [markdown]
# <h3>Insight: Rural accidents often show a stronger correlation because multi-vehicle crashes in rural roads can lead to more casualties.</h3>

# %% [markdown]
# <h2>QUESTION 24: </h2>
# <H2>By light conditions, is number of vehicles correlated with accident severity?</H2>

# %%
light_corr = accident.groupby('Light_Conditions')[['Number_of_Vehicles','Severity_Num']].corr()
print(light_corr)
# Out:
#                                                 Number_of_Vehicles  \
# Light_Conditions
# Darkness - lighting unknown Number_of_Vehicles            1.000000
#                             Severity_Num                 -0.084299
# Darkness - lights lit       Number_of_Vehicles            1.000000
#                             Severity_Num                 -0.114065
# Darkness - lights unlit     Number_of_Vehicles            1.000000
#                             Severity_Num                 -0.109652
# Darkness - no lighting      Number_of_Vehicles            1.000000
#                             Severity_Num                  0.023425
# Daylight                    Number_of_Vehicles            1.000000
#                             Severity_Num                 -0.066680
#
#                                                 Severity_Num
# Light_Conditions
# Darkness - lighting unknown Number_of_Vehicles     -0.084299
#                             Severity_Num            1.000000
# ...

# %% [markdown]
# <h3>Insight: At night (no lighting), severity may correlate more strongly with multi-vehicle crashes because of poor visibility.</h3>

# %% [markdown]
# <h2>QUESTION 25: </h2>
# <H2>By weather conditions, is number of casualties correlated with accident severity?</H2>

# %%
weather_corr = accident.groupby('Weather_Conditions')[['Severity_Num','Number_of_Casualties']].corr()
print(weather_corr)
# Out:
#                                             Severity_Num  Number_of_Casualties
# Weather_Conditions
# Fine + high winds     Severity_Num              1.000000              0.087621
#                       Number_of_Casualties      0.087621              1.000000
# Fine no high winds    Severity_Num              1.000000              0.085677
#                       Number_of_Casualties      0.085677              1.000000
# Fog or mist           Severity_Num              1.000000              0.170617
#                       Number_of_Casualties      0.170617              1.000000
# Other                 Severity_Num              1.000000              0.126508
#                       Number_of_Casualties      0.126508              1.000000
# Raining + high winds  Severity_Num              1.000000              0.100857
#                       Number_of_Casualties      0.100857              1.000000
# Raining no high winds Severity_Num              1.000000              0.092158
# ...

# %% [markdown]
# <h3>Insight: In rainy and foggy weather, accidents tend to have more casualties and higher severity compared to clear weather. This means bad weather not only increases accident risk but also makes accidents more dangerous.</h3>

# %%
accident['Accident Date'] = accident['Accident Date'].astype('str')

# %%
accident['Accident Date'] = accident['Accident Date'].str.strip()
accident['Accident Date'] = accident['Accident Date'].astype('str')
accident['Accident Date'] = accident['Accident Date'].str.replace('/','-')

# %%
accident['Accident Date'] = pd.to_datetime(accident['Accident Date'], dayfirst = True, errors = 'coerce')

# %% [markdown]
# <h1>Adjusting Data Types</h1>

# %%
accident.dtypes
# Out:
# Index                            category
# Accident_Severity                category
# Accident Date              datetime64[ns]
# Latitude                          float64
# Light_Conditions                 category
# District Area                    category
# Longitude                         float64
# Number_of_Casualties                int64
# Number_of_Vehicles                  int64
# Road_Surface_Conditions          category
# Road_Type                        category
# Urban_or_Rural_Area              category
# Weather_Conditions               category
# Vehicle_Type                     category
# Multi_Vehicle                        bool
# Severity_Num                     category
# dtype: object

# %%
accident['Year'] = accident['Accident Date'].dt.year
accident['Month'] = accident['Accident Date'].dt.month
accident['Day'] = accident['Accident Date'].dt.day
accident['DayOfWeek'] = accident['Accident Date'].dt.dayofweek

# %%
accident.isnull().sum()
# Out:
# Index                      0
# Accident_Severity          0
# Accident Date              0
# Latitude                   0
# Light_Conditions           0
# District Area              0
# Longitude                  0
# Number_of_Casualties       0
# Number_of_Vehicles         0
# Road_Surface_Conditions    0
# Road_Type                  0
# Urban_or_Rural_Area        0
# Weather_Conditions         0
# Vehicle_Type               0
# Multi_Vehicle              0
# Severity_Num               0
# Year                       0
# Month                      0
# Day                        0
# DayOfWeek                  0
# dtype: int64

# %% [markdown]
# <h1>Data Visualization</h1>

# %%
camden_accident = accident[accident['District Area'] == 'Camden']

# %%
monthly_camdendata = camden_accident.groupby(['Year', 'Month']).size()

monthly_camdendata = monthly_camdendata.unstack(level=0)

monthly_camdendata.plot(
    marker='o', 
    figsize=(10, 5),
    title='Monthly Road Accidents in camden by Year (2019-2022)'
)
plt.xticks(range(1, 13), ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
# plt.legend(title='Yearly Accident Comparison', bbox_to_anchor = (1.05,1), loc='upper left')
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# <h3>Insight 26:
# Based on the provided graph, the number of monthly road accidents in Camden fluctuated between 2019 and 2022. The single most striking observation is the significant increase in accidents during November 2022, reaching the highest point recorded in the entire four-year period.</h3>

# %%
severity_camden  = camden_accident['Accident_Severity'].value_counts()

plt.pie(severity_camden,
        labels = severity_camden.index,
        autopct = '%1.1f%%',
        startangle = 90)
plt.gcf().set_size_inches(10,7)
plt.title('Accident Severity Distribution')
plt.show()

severity_2022_camden = camden_accident[camden_accident['Year'] == 2022]
# severity_2019
lsc_2022 = severity_2022_camden['Accident_Severity'].value_counts()

plt.pie(lsc_2022,
        labels = lsc_2022.index,
        autopct = '%1.1f%%',
        startangle = 90)
plt.gcf().set_size_inches(10,7)
plt.title('Accident Severity Distribution')
plt.show()

# %% [markdown]
# <h3>Insight 27: In both charts, slight accidents make up the largest portion by a wide margin (85.3% in the top chart and 87.4% in the bottom chart), while fatal and serious accidents combined represent a small minority of the total accidents.</h3>

# %%
# Accidents per year
accidents_per_year = camden_accident['Year'].value_counts().sort_index()
accidents_per_month = camden_accident['Month'].value_counts().sort_index()
accidents_per_day = camden_accident['DayOfWeek'].value_counts().sort_index()


#PER YEAR 
accidents_per_year.plot(kind='bar')
plt.title('Accidents per Year')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.show()

month_names = {
    1: 'January', 2: 'February', 3: 'March', 4: 'April',
    5: 'May', 6: 'June', 7: 'July', 8: 'August',
    9: 'September', 10: 'October', 11: 'November', 12: 'December'
}

# Replace numerical months with their names
accidents_per_month.index = accidents_per_month.index.map(month_names)


accidents_per_month.plot(kind='bar')
plt.title('Accidents per Month')
plt.xlabel('Month')
plt.ylabel('Number of Accidents')
plt.show()


#accident per day
day_names = {
    0: 'Monday',
    1: 'Tuesday',
    2: 'Wednesday',
    3: 'Thursday',
    4: 'Friday',
    5: 'Saturday',
    6: 'Sunday'
}

accidents_per_day.index = accidents_per_day.index.map(day_names)
accidents_per_day.plot(kind='bar')
print(accidents_per_day)
# Out:
# DayOfWeek
# Monday       303
# Tuesday      426
# Wednesday    517
# Thursday     506
# Friday       507
# Saturday     526
# Sunday       363
# Name: count, dtype: int64

# %% [markdown]
# <h3>Insight 28: The number of accidents in the area increased each year from 2019 to 2022, with 2022 having the most accidents overall. Additionally, the most accidents generally happen in the middle of the year (May, June, and July) and on the weekends (Friday and Saturday).</h3>

# %%
RC_accident = accident[accident['District Area'] == 'Redcar and Cleveland']

# %%
monthly_RCdata = RC_accident.groupby(['Year', 'Month']).size()

monthly_RCdata = monthly_RCdata.unstack(level=0)

monthly_RCdata.plot(
    marker='o', 
    figsize=(10, 5),
    title='Monthly Road Accidents in Redcar and Cleveland by Year (2019-2022)'
)
plt.xticks(range(1, 13), ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
# plt.legend(title='Yearly Accident Comparison', bbox_to_anchor = (1.05,1), loc='upper left')
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# <h3>Insight 29:
# Based on the provided graph, the number of road accidents in Redcar and Cleveland was highest in August 2020, reaching the peak for the entire four-year period from 2019 to 2022.</h3>

# %%
pip install folium
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\Leenitte\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import folium
from folium.plugins import HeatMap

# %%
locations = list(zip(RC_accident['Latitude'],RC_accident['Longitude']))
m = folium.Map(location=[RC_accident['Latitude'].mean(),RC_accident['Longitude'].mean()],zoom_start=10)
HeatMap(locations).add_to(m)
m.save('accident_heatmap.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
locations = list(zip(camden_accident['Latitude'],camden_accident['Longitude']))
m = folium.Map(location=[camden_accident['Latitude'].mean(),camden_accident['Longitude'].mean()],zoom_start=10)
HeatMap(locations).add_to(m)
m.save('accident_heatmap.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
# for i in accident['District Area'].unique():
#     print(i)

# %%
bexley_accident = accident[accident['District Area'] == 'Bexley']

# %%
monthly_bexleydata = bexley_accident.groupby(['Year', 'Month']).size()

monthly_bexleydata = monthly_bexleydata.unstack(level=0)

monthly_bexleydata.plot(
    marker='o', 
    figsize=(10, 5),
    title='Monthly Road Accidents in Bexley by Year (2019-2022)'
)
plt.xticks(range(1, 13), ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
plt.legend(title='Yearly Accident Comparison', bbox_to_anchor = (1.05,1), loc='upper left')
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# <h3>Insight 30: Based on the graph, the number of road accidents in Bexley has generally increased over the years. Specifically, the number of accidents in November 2021 was the highest recorded in the entire four-year period from 2019 to 2022.</h3>

# %%
locations = list(zip(bexley_accident['Latitude'],bexley_accident['Longitude']))
m = folium.Map(location=[bexley_accident['Latitude'].mean(),bexley_accident['Longitude'].mean()],zoom_start=10)
HeatMap(locations).add_to(m)
m.save('accident_heatmap.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
kennet_accident = accident[accident['District Area'] == 'Kennet']

# %%
monthly_kennetdata = kennet_accident.groupby(['Year', 'Month']).size()

monthly_kennetdata = monthly_kennetdata.unstack(level=0)

monthly_kennetdata.plot(
    marker='o', 
    figsize=(10, 5),
    title='Monthly Road Accidents in Bexley by Year (2019-2022)'
)
plt.xticks(range(1, 13), ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
plt.legend(title='Yearly Accident Comparison', bbox_to_anchor = (1.05,1), loc='upper left')
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# <H3>Insight 31: Based on the graph, the most significant insight is that the number of road accidents in Kennet has fluctuated, with a notable peak in February 2020 being the highest recorded number of accidents during the entire three-year period.</H3>

# %%
locations = list(zip(kennet_accident['Latitude'],kennet_accident['Longitude']))
m = folium.Map(location=[kennet_accident['Latitude'].mean(),kennet_accident['Longitude'].mean()],zoom_start=10)
HeatMap(locations).add_to(m)
m.save('accident_heatmap.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
for i in accident['District Area'].unique():
    print(i)
# Out:
# Kensington and Chelsea
# Westminster
# Richmond upon Thames
# Hammersmith and Fulham
# Hounslow
# Tower Hamlets
# City of London
# Southwark
# Camden
# Hackney
# Islington
# Barnet
# Brent
# Haringey
# Merton
# Ealing
# Enfield
# Greenwich
# Newham
# London Airport (Heathrow)
# Hillingdon
# Waltham Forest
# Redbridge
# Barking and Dagenham
# Bromley
# Havering
# Croydon
# Lambeth
# Wandsworth
# Sutton
# Bexley
# Lewisham
# Harrow
# Kingston upon Thames
# Barrow-in-Furness
# South Lakeland
# Carlisle
# Eden
# Allerdale
# Copeland
# Fylde
# Blackpool
# Wyre
# Lancaster
# Chorley
# West Lancashire
# South Ribble
# Preston
# Blackburn with Darwen
# Hyndburn
# Ribble Valley
# Burnley
# Pendle
# Rossendale
# Wirral
# Liverpool
# Sefton
# Knowsley
# St. Helens
# Manchester
# Salford
# Tameside
# Stockport
# Bolton
# Wigan
# Trafford
# Bury
# Rochdale
# Oldham
# Chester
# Vale Royal
# Halton
# Warrington
# Crewe and ntwich
# Ellesmere Port and Neston
# Congleton
# Macclesfield
# ...

# %%
cornwall_accident = accident[accident['District Area'] == 'Cornwall']

# %%
accidents_per_year = cornwall_accident['Year'].value_counts().sort_index()
accidents_per_month = cornwall_accident['Month'].value_counts().sort_index()
accidents_per_day = cornwall_accident['DayOfWeek'].value_counts().sort_index()


#PER YEAR 
accidents_per_year.plot(kind='bar')
plt.title('Accidents per Year')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.show()

# %%
locations = list(zip(kennet_accident['Latitude'],kennet_accident['Longitude']))
m = folium.Map(location=[kennet_accident['Latitude'].mean(),kennet_accident['Longitude'].mean()],zoom_start=10)
HeatMap(locations).add_to(m)
m.save('accident_heatmap.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
falkirk_accident = accident[accident['District Area'] == 'Falkirk']

# %%
accidents_per_year = falkirk_accident['Year'].value_counts().sort_index()
accidents_per_month = falkirk_accident['Month'].value_counts().sort_index()
accidents_per_day = falkirk_accident['DayOfWeek'].value_counts().sort_index()


#PER YEAR 
accidents_per_year.plot(kind='bar')
plt.title('Accidents per Year')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.show()

# %%
locations = list(zip(falkirk_accident['Latitude'],falkirk_accident['Longitude']))
m = folium.Map(location=[falkirk_accident['Latitude'].mean(),falkirk_accident['Longitude'].mean()],zoom_start=10)
HeatMap(locations).add_to(m)
m.save('accident_heatmap.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...
